# %%
import pandas as pd
from pandas import DataFrame
import random

# %%
df = pd.read_csv('jd_comments.csv',header=None)
df
# Out:
#                        0                                                  1  \
# 0    二手apple 37245978364  7月31号下的单，三天后才开始发物流，8月5日才收到货。中间停止的时间比较长，虽然发的是京东...
# 1    二手apple 37245978364    手机收到了，没有立马来评论，而是试用了一个星期。感觉不错，外观跟新的一样。系统流畅！值得购买。
# 2    二手apple 37245978364                    总体还算可以，小瑕疵，电池91%,目前用着没什么毛病，贵哦去牛
# 3    二手apple 37245978364                                   还可以，用了两天，还不错，满意。
# 4    二手apple 37245978365  收到货了，物流是从杭州发过来的，速度越来越快，打开了有惊喜，非常棒，成色非常新，很漂亮！就是...
# ..                   ...                                                ...
# 585  二手apple 37245978364        差评。亲身经过。都是套路。产品质量很一般，售后服务态度更是差。建议想买的朋友三思而行，
# 586  二手apple 37245978364                                 别买手机出现问题不负责的差评差评差评
# 587  二手apple 37245978364                                            差评，特别不好
# 588  二手apple 37245978364  手机很垃圾，屏幕要么是@差就是显示有斑点什么都毛病很多，我换了很多次还是一样大家千万别相信别...
# 589  二手apple 37245978364  感觉这个手机挺垃圾的。建议大家不要买。不如去实体店看看。这手机维修过。电池也是换过的。也就是...
#
#      2                    3
# ...

# %%
df.columns
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
df.iloc[:,1]
# Out:
# 0      7月31号下的单，三天后才开始发物流，8月5日才收到货。中间停止的时间比较长，虽然发的是京东...
# 1        手机收到了，没有立马来评论，而是试用了一个星期。感觉不错，外观跟新的一样。系统流畅！值得购买。
# 2                        总体还算可以，小瑕疵，电池91%,目前用着没什么毛病，贵哦去牛
# 3                                       还可以，用了两天，还不错，满意。
# 4      收到货了，物流是从杭州发过来的，速度越来越快，打开了有惊喜，非常棒，成色非常新，很漂亮！就是...
#                              ...
# 585          差评。亲身经过。都是套路。产品质量很一般，售后服务态度更是差。建议想买的朋友三思而行，
# 586                                   别买手机出现问题不负责的差评差评差评
# 587                                              差评，特别不好
# 588    手机很垃圾，屏幕要么是@差就是显示有斑点什么都毛病很多，我换了很多次还是一样大家千万别相信别...
# 589    感觉这个手机挺垃圾的。建议大家不要买。不如去实体店看看。这手机维修过。电池也是换过的。也就是...
# Name: 1, Length: 590, dtype: object

# %%
df1 = df.drop([0,3],axis=1)
df1
# Out:
#                                                      1  2
# 0    7月31号下的单，三天后才开始发物流，8月5日才收到货。中间停止的时间比较长，虽然发的是京东...  3
# 1      手机收到了，没有立马来评论，而是试用了一个星期。感觉不错，外观跟新的一样。系统流畅！值得购买。  3
# 2                      总体还算可以，小瑕疵，电池91%,目前用着没什么毛病，贵哦去牛  3
# 3                                     还可以，用了两天，还不错，满意。  3
# 4    收到货了，物流是从杭州发过来的，速度越来越快，打开了有惊喜，非常棒，成色非常新，很漂亮！就是...  3
# ..                                                 ... ..
# 585        差评。亲身经过。都是套路。产品质量很一般，售后服务态度更是差。建议想买的朋友三思而行，  1
# 586                                 别买手机出现问题不负责的差评差评差评  1
# 587                                            差评，特别不好  1
# 588  手机很垃圾，屏幕要么是@差就是显示有斑点什么都毛病很多，我换了很多次还是一样大家千万别相信别...  1
# 589  感觉这个手机挺垃圾的。建议大家不要买。不如去实体店看看。这手机维修过。电池也是换过的。也就是...  1
#
# [590 rows x 2 columns]

# %%
df_poor = df1[df1[2]==1]

# %%
df_poor[1].to_csv('neg.txt',sep='\t',index=False)
# Out:
# /Users/tongmingmedia/Library/Python/3.6/lib/python/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
df_good = df1[df1[2]==3]
df_good
# Out:
#                                                      1  2
# 0    7月31号下的单，三天后才开始发物流，8月5日才收到货。中间停止的时间比较长，虽然发的是京东...  3
# 1      手机收到了，没有立马来评论，而是试用了一个星期。感觉不错，外观跟新的一样。系统流畅！值得购买。  3
# 2                      总体还算可以，小瑕疵，电池91%,目前用着没什么毛病，贵哦去牛  3
# 3                                     还可以，用了两天，还不错，满意。  3
# 4    收到货了，物流是从杭州发过来的，速度越来越快，打开了有惊喜，非常棒，成色非常新，很漂亮！就是...  3
# ..                                                 ... ..
# 525                                                 还行  3
# 526                                                 不错  3
# 527                                                 明明  3
# 528                                                 很好  3
# 529                                                  好  3
#
# [530 rows x 2 columns]

# %%
df_good[1].to_csv('pos.txt',sep='\t',index=False)
# Out:
# /Users/tongmingmedia/Library/Python/3.6/lib/python/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                        0                                                  1  \
# 0    二手apple 37245978364  7月31号下的单，三天后才开始发物流，8月5日才收到货。中间停止的时间比较长，虽然发的是京东...
# 1    二手apple 37245978364    手机收到了，没有立马来评论，而是试用了一个星期。感觉不错，外观跟新的一样。系统流畅！值得购买。
# 2    二手apple 37245978364                    总体还算可以，小瑕疵，电池91%,目前用着没什么毛病，贵哦去牛
# 3    二手apple 37245978364                                   还可以，用了两天，还不错，满意。
# 4    二手apple 37245978365  收到货了，物流是从杭州发过来的，速度越来越快，打开了有惊喜，非常棒，成色非常新，很漂亮！就是...
# ..                   ...                                                ...
# 585  二手apple 37245978364        差评。亲身经过。都是套路。产品质量很一般，售后服务态度更是差。建议想买的朋友三思而行，
# 586  二手apple 37245978364                                 别买手机出现问题不负责的差评差评差评
# 587  二手apple 37245978364                                            差评，特别不好
# 588  二手apple 37245978364  手机很垃圾，屏幕要么是@差就是显示有斑点什么都毛病很多，我换了很多次还是一样大家千万别相信别...
# 589  二手apple 37245978364  感觉这个手机挺垃圾的。建议大家不要买。不如去实体店看看。这手机维修过。电池也是换过的。也就是...
#
#      2                    3
# ...

# %%
df[df[2]==3].iloc[:,1]
# Out:
# 0      7月31号下的单，三天后才开始发物流，8月5日才收到货。中间停止的时间比较长，虽然发的是京东...
# 1        手机收到了，没有立马来评论，而是试用了一个星期。感觉不错，外观跟新的一样。系统流畅！值得购买。
# 2                        总体还算可以，小瑕疵，电池91%,目前用着没什么毛病，贵哦去牛
# 3                                       还可以，用了两天，还不错，满意。
# 4      收到货了，物流是从杭州发过来的，速度越来越快，打开了有惊喜，非常棒，成色非常新，很漂亮！就是...
#                              ...
# 525                                                   还行
# 526                                                   不错
# 527                                                   明明
# 528                                                   很好
# 529                                                    好
# Name: 1, Length: 530, dtype: object

# %%
df[:,1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-3b12c41b371c> in <module>
# ----> 1 df[:,1]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2973             if self.columns.nlevels > 1:
#    2974                 return self._getitem_multilevel(key)
# -> 2975             indexer = self.columns.get_loc(key)
#    2976             if is_integer(indexer):
#    2977                 indexer = [indexer]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888                 )
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#    2892                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
df = pd.read_csv('neg.txt',sep='\t',header=None)
df
# Out:
#                                                     0
# 0           评论里个个买九新都说没使用痕迹 为什么我买九新的连七新都达不到 两个地方摔得很严重
# 1          你们~买过来我这里拿，我送给你们，本来相信京东没假货，碰到一个这样的商家，当喂狗了。
# 2   各位网友你们好！在此真诚提醒(被坑亲身经历)千万别买，因下雨时屏幕被淋雨水导致手机直接瘫痪、...
# 3                         还说是九成新的，到手一看五成新都没有，其实一星都不想给
# 4   太差了，表面损毁严重！连最基本的屏幕都没擦干净，太不用心了！就这服务态度只能给零分！强烈要求退货！
# 5   买前必看！！！最恶心购物经历，没有比这次更坏的。买了三天充不了电，寄回去退。厉害了，先说要检...
# 6   4000多的手机。买来不到一天震动烧了。外放扬声器烧了。前摄像头有灰。明明就是拆过或者是组装...
# 7   首先手机真的很差差到什么地步你让我慢慢给你们讲，售后态度很差恶劣！还骂人！！！明知道自己的问...
# 8   手机很垃圾，屏幕要么是@差就是显示有斑点什么都毛病很多，我换了很多次还是一样大家千万别相信别...
# 9   绝对是我买过的最差的东西，4000几的东西，说是京东检测没问题发货的，手机几秒就重新启动一次...
# 10      买了不到十天电池就坏了，手机质量不是一般的差，请大家不要在此商家购买。售后服务态度也很差。
# 11  手机在使用了两天，屏幕内侧黑屏！一阵可以亮一阵不亮，没摔没碰！ 手机是2017年的  使用了...
# 12  手机肯定浸过水 换过内屏，因为屏幕太不灵敏了啊，很难操控的感觉，前摄像头打开拍照 是瞬间白屏...
# 13  使用一个多月了，真坑、经鉴定是修过的，应该还是大修，屏幕明显感觉有条缝，防水是不指望了，估计...
# 14                    用了一个多月就坏了，拿去修屏幕是假苹果屏幕，用了我一千多来假。
# 15  手机刚到的时候，总是自动重启，卖家让我恢复出厂设置。后来没过几天手机直接关机开不了机。联系卖...
# ...

# %%
df.head(5)
# Out:
#                      0                                                  1  2  \
# 0  二手apple 37245978364  7月31号下的单，三天后才开始发物流，8月5日才收到货。中间停止的时间比较长，虽然发的是京东...  3
# 1  二手apple 37245978364    手机收到了，没有立马来评论，而是试用了一个星期。感觉不错，外观跟新的一样。系统流畅！值得购买。  3
# 2  二手apple 37245978364                    总体还算可以，小瑕疵，电池91%,目前用着没什么毛病，贵哦去牛  3
# 3  二手apple 37245978364                                   还可以，用了两天，还不错，满意。  3
# 4  二手apple 37245978365  收到货了，物流是从杭州发过来的，速度越来越快，打开了有惊喜，非常棒，成色非常新，很漂亮！就是...  3
#
#                      3
# 0  2019-08-06 11:55:30
# 1  2019-05-29 11:14:53
# 2  2019-06-21 22:02:08
# 3  2019-01-31 02:13:00
# 4  2019-08-20 17:36:42

# %%
df
# Out:
#                        0                                                  1  \
# 0    二手apple 37245978364  7月31号下的单，三天后才开始发物流，8月5日才收到货。中间停止的时间比较长，虽然发的是京东...
# 1    二手apple 37245978364    手机收到了，没有立马来评论，而是试用了一个星期。感觉不错，外观跟新的一样。系统流畅！值得购买。
# 2    二手apple 37245978364                    总体还算可以，小瑕疵，电池91%,目前用着没什么毛病，贵哦去牛
# 3    二手apple 37245978364                                   还可以，用了两天，还不错，满意。
# 4    二手apple 37245978365  收到货了，物流是从杭州发过来的，速度越来越快，打开了有惊喜，非常棒，成色非常新，很漂亮！就是...
# ..                   ...                                                ...
# 585  二手apple 37245978364        差评。亲身经过。都是套路。产品质量很一般，售后服务态度更是差。建议想买的朋友三思而行，
# 586  二手apple 37245978364                                 别买手机出现问题不负责的差评差评差评
# 587  二手apple 37245978364                                            差评，特别不好
# 588  二手apple 37245978364  手机很垃圾，屏幕要么是@差就是显示有斑点什么都毛病很多，我换了很多次还是一样大家千万别相信别...
# 589  二手apple 37245978364  感觉这个手机挺垃圾的。建议大家不要买。不如去实体店看看。这手机维修过。电池也是换过的。也就是...
#
#      2                    3
# ...

# %%
df.iloc[0,1]
# Out:
# '7月31号下的单，三天后才开始发物流，8月5日才收到货。中间停止的时间比较长，虽然发的是京东物物流，感觉真的是太慢了，远远比不上京东自营的物流速度，这发货速度与物流速度有待提高。手机收到了就立马试用，机子手感很好，运作也很流畅，整体还算满意。'

# %%
rand = random.randint(0,df.shape[0])
rand
# Out:
# 75

# %%
df.iloc[2]
# Out:
# 0                二手apple 37245978364
# 1    总体还算可以，小瑕疵，电池91%,目前用着没什么毛病，贵哦去牛
# 2                                  3
# 3                2019-06-21 22:02:08
# Name: 2, dtype: object

# %%
import numpy as np
dft = DataFrame(np.random.randint(0,10,size=(3,4)))
dft
# Out:
#    0  1  2  3
# 0  8  2  1  2
# 1  6  7  1  4
# 2  0  8  6  1

# %%
la = lambda x: x+1

# %%
la([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-831fa9f0fbf8> in <module>
# ----> 1 la([1,2,3])
#
# <ipython-input-66-62c2bbbbc011> in <lambda>(x)
# ----> 1 la = lambda x: x+1
#
# TypeError: can only concatenate list (not "int") to list

# %%
la(dft[3])
# Out:
# 0    3
# 1    5
# 2    2
# Name: 3, dtype: int64

# %%
dft
# Out:
#    0  1  2  3
# 0  8  2  1  2
# 1  6  7  1  4
# 2  0  8  6  1

# %%
from snownlp import SnowNLP

# %%
s = SnowNLP('我是好人')

# %%
s.sentiments
# Out:
# 0.8999999999999999

# %%
s1 = SnowNLP(df.iloc[2,1])

# %%
s1

# %%
type(s1.sentiments)
# Out:
# float

# %%
tt = s1.sentiments

# %%
tt
# Out:
# 0.8000672246445277

# %%
round(tt, 2)
# Out:
# 0.8

# %%
ttt = 0.81

# %%
round(ttt,2)
# Out:
# 0.81

# %%
dft
# Out:
#    0  1  2  3
# 0  8  2  1  2
# 1  6  7  1  4
# 2  0  8  6  1

# %%
r = [7,7,7]

# %%
dfr = DataFrame(r)

# %%
dfr
# Out:
#    0
# 0  7
# 1  7
# 2  7

# %%
type(dfr)
# Out:
# pandas.core.frame.DataFrame

# %%
dft.merge(dfr, how='inner')
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3]
# Index: []

# %%
dft[4] = [1,2,1]

# %%
dft
# Out:
#    0  1  2  3  4
# 0  8  2  1  2  1
# 1  6  7  1  4  2
# 2  0  8  6  1  1

# %%
dft
# Out:
#    0  1  2  3
# 0  8  2  1  2
# 1  6  7  1  4
# 2  0  8  6  1

# %%
dft.append(dfr)
# Out:
#    0    1    2    3
# 0  8  2.0  1.0  2.0
# 1  6  7.0  1.0  4.0
# 2  0  8.0  6.0  1.0
# 0  7  NaN  NaN  NaN
# 1  7  NaN  NaN  NaN
# 2  7  NaN  NaN  NaN

# %%
df
# Out:
#                        0                                                  1  \
# 0    二手apple 37245978364  7月31号下的单，三天后才开始发物流，8月5日才收到货。中间停止的时间比较长，虽然发的是京东...
# 1    二手apple 37245978364    手机收到了，没有立马来评论，而是试用了一个星期。感觉不错，外观跟新的一样。系统流畅！值得购买。
# 2    二手apple 37245978364                    总体还算可以，小瑕疵，电池91%,目前用着没什么毛病，贵哦去牛
# 3    二手apple 37245978364                                   还可以，用了两天，还不错，满意。
# 4    二手apple 37245978365  收到货了，物流是从杭州发过来的，速度越来越快，打开了有惊喜，非常棒，成色非常新，很漂亮！就是...
# ..                   ...                                                ...
# 585  二手apple 37245978364        差评。亲身经过。都是套路。产品质量很一般，售后服务态度更是差。建议想买的朋友三思而行，
# 586  二手apple 37245978364                                 别买手机出现问题不负责的差评差评差评
# 587  二手apple 37245978364                                            差评，特别不好
# 588  二手apple 37245978364  手机很垃圾，屏幕要么是@差就是显示有斑点什么都毛病很多，我换了很多次还是一样大家千万别相信别...
# 589  二手apple 37245978364  感觉这个手机挺垃圾的。建议大家不要买。不如去实体店看看。这手机维修过。电池也是换过的。也就是...
#
#      2                    3
# ...

# %%
df.shape
# Out:
# (590, 4)

# %%
dft
# Out:
#    0  1  2  3  4
# 0  8  2  1  2  1
# 1  6  7  1  4  2
# 2  0  8  6  1  1

# %%
dft.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
dft.index = [4,5,6]

# %%
dft
# Out:
#    0  1  2  3  4
# 4  8  2  1  2  1
# 5  6  7  1  4  2
# 6  0  8  6  1  1

# %%
dft.index = ['4','5','6']
dft
# Out:
#    0  1  2  3  4
# 4  8  2  1  2  1
# 5  6  7  1  4  2
# 6  0  8  6  1  1

# %%
columns = ['gosssod', 'content', 'eval', 'created_at', 'prob']
dft.columns = columns
dft
# Out:
#    gosssod  content  eval  created_at  prob
# 4        8        2     1           2     1
# 5        6        7     1           4     2
# 6        0        8     6           1     1

# %%
dft.loc[:,['eval','prob']]
# Out:
#    eval  prob
# 4     1     1
# 5     1     2
# 6     6     1

# %%
dft[dft['eval']==1]
# Out:
#    gosssod  content  eval  created_at  prob
# 4        8        2     1           2     1
# 5        6        7     1           4     2

# %%
dft
# Out:
#    gosssod  content  eval  created_at  prob
# 4        8        2     1           2     1
# 5        6        7     1           4     2
# 6        0        8     6           1     1

# %%
dft['eval'].map({1: 0, 6: 4})
# Out:
# 4    0
# 5    0
# 6    4
# Name: eval, dtype: int64

# %%
f = 0.23456

# %%
round(f)
# Out:
# 0

# %%
df
# Out:
#                        0                                                  1  \
# 0    二手apple 37245978364  7月31号下的单，三天后才开始发物流，8月5日才收到货。中间停止的时间比较长，虽然发的是京东...
# 1    二手apple 37245978364    手机收到了，没有立马来评论，而是试用了一个星期。感觉不错，外观跟新的一样。系统流畅！值得购买。
# 2    二手apple 37245978364                    总体还算可以，小瑕疵，电池91%,目前用着没什么毛病，贵哦去牛
# 3    二手apple 37245978364                                   还可以，用了两天，还不错，满意。
# 4    二手apple 37245978365  收到货了，物流是从杭州发过来的，速度越来越快，打开了有惊喜，非常棒，成色非常新，很漂亮！就是...
# ..                   ...                                                ...
# 585  二手apple 37245978364        差评。亲身经过。都是套路。产品质量很一般，售后服务态度更是差。建议想买的朋友三思而行，
# 586  二手apple 37245978364                                 别买手机出现问题不负责的差评差评差评
# 587  二手apple 37245978364                                            差评，特别不好
# 588  二手apple 37245978364  手机很垃圾，屏幕要么是@差就是显示有斑点什么都毛病很多，我换了很多次还是一样大家千万别相信别...
# 589  二手apple 37245978364  感觉这个手机挺垃圾的。建议大家不要买。不如去实体店看看。这手机维修过。电池也是换过的。也就是...
#
#      2                    3
# ...

# %%
dft = DataFrame({'eval': [1,1,2,2,3,3], 'prob':[1,1,2,3,4,5]})
dft
# Out:
#    eval  prob
# 0     1     1
# 1     1     1
# 2     2     2
# 3     2     3
# 4     3     4
# 5     3     5

# %%
dft['eval']==dft['prob']
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
dft[dft['eval']==dft['prob']].shape[0]
# Out:
# 3

# %%
result = pd.read_csv('result.csv', )
result
# Out:
#                                                content  eval  prob
# 0    7月31号下的单，三天后才开始发物流，8月5日才收到货。中间停止的时间比较长，虽然发的是京东...     1     1
# 1      手机收到了，没有立马来评论，而是试用了一个星期。感觉不错，外观跟新的一样。系统流畅！值得购买。     1     1
# 2                      总体还算可以，小瑕疵，电池91%,目前用着没什么毛病，贵哦去牛     1     1
# 3                                     还可以，用了两天，还不错，满意。     1     1
# 4    收到货了，物流是从杭州发过来的，速度越来越快，打开了有惊喜，非常棒，成色非常新，很漂亮！就是...     1     1
# ..                                                 ...   ...   ...
# 585        差评。亲身经过。都是套路。产品质量很一般，售后服务态度更是差。建议想买的朋友三思而行，     0     0
# 586                                 别买手机出现问题不负责的差评差评差评     0     0
# 587                                            差评，特别不好     0     0
# 588  手机很垃圾，屏幕要么是@差就是显示有斑点什么都毛病很多，我换了很多次还是一样大家千万别相信别...     0     0
# 589  感觉这个手机挺垃圾的。建议大家不要买。不如去实体店看看。这手机维修过。电池也是换过的。也就是...     0     0
#
# [590 rows x 3 columns]
